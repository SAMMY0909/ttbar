# %%
from ROOT import TFile
import matplotlib.pyplot as plt

import numpy as np
f=TFile('a1_mv2c10_reg.root')
h_0=f.Get('mv2c10_0')
h_2=f.Get('mv2c10_2')
x_vals1 = np.array([h_2.Integral(i,-1)/h_2.Integral(0,-1) for i in range(101)])
y_vals1 = np.array([0 for i in range(101)])
for i in range(101):
    if(h_0.Integral(i,-1)!=0):
        y_vals1[i] = (h_0.Integral(0,-1)/float(h_0.Integral(i,-1)))
    elif(h_0.Integral(i,-1)==0):
        y_vals1[i] = 0
plt.plot(x_vals1,y_vals1,"-b", label="tt-bar d0max=5.0mm,z0max=5.0mm,light jet rejection mv2c10")


f1=TFile('a1_mv2c10_mod.root')
h_01=f1.Get('mv2c10_0')
h_21=f1.Get('mv2c10_2')
x_vals01 = [h_21.Integral(i,-1)/h_21.Integral(0,-1) for i in range(101)]
y_vals01 = [0 for i in range(101)]
for i in range(101):
    if(h_01.Integral(i,-1)!=0):
        y_vals01[i] = (h_01.Integral(0,-1)/float(h_01.Integral(i,-1)))
    elif(h_01.Integral(i,-1)==0):
        y_vals01[i] = 0
plt.plot(x_vals01,y_vals01,"-r", label="tt-bar d0max=7.5mm,z0max=7.5mm,light jet rejection mv2c10")

'''
f3=TFile('mv2c_mod1.root')
h_03=f3.Get('mv2c10_0')
h_31=f3.Get('mv2c10_2')
x_vals3 = [h_31.Integral(i,-1)/h_31.Integral(0,-1) for i in range(101)]
y_vals3 = [h_03.Integral(0,-1)/h_03.Integral(i,-1) for i in range(101)]
plt.plot(x_vals3,y_vals3,"-g", label="d0max=7.5mm,z0max=7.5mm,light jet rejection mv2c10")
'''
plt.xlabel('b-tagging efficiency')
plt.ylabel('light jet rejection')
plt.legend(loc="upper left")
plt.savefig('bte_ljr_reg_mv2c10.png')
plt.show()


plt.figure(1)
h_1=f.Get('mv2c10_1')
x_vals2 = [h_1.Integral(i,-1)/h_1.Integral(0,-1) for i in range(101)]
y_vals2 = [0 for i in range(101)]
for k in range(101):
    if(h_0.Integral(k,-1)!=0):
        y_vals2[k] = (h_0.Integral(0,-1)/float(h_0.Integral(k,-1)))
    elif(h_0.Integral(k,-1)==0):
        y_vals2[k] = 0
plt.plot(x_vals2,y_vals2,"-b", label="tt-bar d0max=5.0mm,z0max=5.0mm, c jet rejection mv2c10")

h_11=f1.Get('mv2c10_1')
x_vals11 = [h_11.Integral(i,-1)/h_11.Integral(0,-1) for i in range(101)]
y_vals11 = [0 for i in range(101)]
for k in range(101):
    if(h_01.Integral(k,-1)!=0):
        y_vals11[k] = (h_01.Integral(0,-1)/float(h_01.Integral(k,-1)))
    elif(h_01.Integral(k,-1)==0):
        y_vals11[k] = 0
plt.plot(x_vals11,y_vals11,"-r", label="tt-bar d0max=7.5mm,z0max=7.5mm, c jet rejection mv2c10")


'''
h_33=f3.Get('mv2c10_1')
x_vals33 = [h_33.Integral(i,-1)/h_33.Integral(0,-1) for i in range(101)]
y_vals33 = [h_03.Integral(0,-1)/h_03.Integral(i,-1) for i in range(101)]
plt.plot(x_vals33,y_vals33,"-g", label="d0max=7.5mm,z0max=7.5mm, c jet rejection mv2c10")
'''
plt.xlabel('b-tagging efficiency')
plt.ylabel('c jet rejection')
plt.legend(loc="upper left")
plt.savefig('bte_cjr_reg_mv2c10.png')
plt.show()
